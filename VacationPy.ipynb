# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="c1cb4cfc-9c97-47ec-a3da-6e27660e8d55" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID            City      Lat       Lng  Max Temp  Humidity  \
# 0        0         emerald -23.5333  148.1667     74.98        42
# 1        1       papatowai -46.5619  169.4708     51.19        88
# 2        2  puerto natales -51.7236  -72.4875     46.04        86
# 3        3    faya-largeau  17.9257   19.1043     75.85        18
# 4        4         klyuchi  52.2667   79.1667     33.44        79
#
#         Cloudiness  Cloudiness Numberical  Wind Speed Country  \
# 0    broken clouds                     84       12.24      AU
# 1  overcast clouds                    100        6.76      NZ
# 2       light rain                    100        5.14      CL
# 3  overcast clouds                     98       17.52      TD
# 4  overcast clouds                     95       20.09      RU
#
#                   Date
# 0  2025-03-06 15:14:32
# 1  2025-03-06 15:14:34
# 2  2025-03-06 15:14:35
# 3  2025-03-06 15:14:36
# 4  2025-03-06 15:14:37

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display


humidity_plot = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo=True,
    tiles="OSM",
    frame_width=750,
    frame_height=500,
    size= "Humidity",
    title="Map of Cities with Humidity Levels",
    color="City",
    legend = "right",
)


# Display the map
humidity_plot
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %%
#checking the data for description
city_data_df.describe()
# Out:
#           City_ID         Lat         Lng    Max Temp    Humidity  \
# count  574.000000  574.000000  574.000000  574.000000  574.000000
# mean   286.500000   17.704919   16.783475   56.976324   72.918118
# std    165.843802   32.740959   89.271525   26.630841   20.650467
# min      0.000000  -54.800000 -178.166700  -44.250000   10.000000
# 25%    143.250000  -10.380925  -61.635825   41.027500   60.000000
# 50%    286.500000   20.691800   20.466700   64.290000   77.000000
# 75%    429.750000   44.260100   89.990350   78.355000   89.000000
# max    573.000000   78.218600  177.483300  101.300000  100.000000
#
#        Cloudiness Numberical  Wind Speed
# count             574.000000  574.000000
# mean               58.979094    8.739495
# std                40.689771    6.036757
# min                 0.000000    0.000000
# 25%                16.000000    3.985000
# 50%                75.000000    7.380000
# 75%               100.000000   12.427500
# ...

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
best_weather = city_data_df[
    (city_data_df["Max Temp"] < 79)
    & (city_data_df["Max Temp"] > 60)
    & (city_data_df["Wind Speed"] < 25)
    & (city_data_df["Cloudiness Numberical"] < 40)
    & (city_data_df["Humidity"] < 50)
    & (city_data_df["Humidity"] > 20)
]


# Drop any rows with null values (chat gpt suggestion)
best_weather = best_weather.dropna()
# Reset the index (chat gpt suggestion)
best_weather.reset_index(drop=True, inplace=True)

# Display sample data
best_weather
# Out:
#     City_ID           City      Lat       Lng  Max Temp  Humidity Cloudiness  \
# 0        85    gulf shores  30.2460  -87.7008     65.43        31  clear sky
# 1       127   san patricio  28.0170  -97.5169     78.75        39  clear sky
# 2       199   stephenville  32.2207  -98.2023     67.24        26  clear sky
# 3       207        suances  43.4334   -4.0434     64.24        45  clear sky
# 4       275    broken hill -31.9500  141.4333     70.05        34  clear sky
# 5       300  alice springs -23.7000  133.8833     67.55        40  clear sky
# 6       366        badiyah  22.4500   58.8000     70.65        35  clear sky
# 7       395         chinde  26.8212   87.7095     60.73        37  clear sky
# 8       433           tura  25.5198   90.2201     60.57        31  clear sky
# 9       460         turbat  26.0023   63.0440     74.44        26  clear sky
# 10      495       calvinia -31.4707   19.7760     75.58        30  clear sky
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = best_weather[["City", "Country", "Lat", "Lng", "Humidity"]].copy()#looked up on google how to copy a dataframe

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df
# Out:
#              City Country      Lat       Lng  Humidity Hotel Name
# 0     gulf shores      US  30.2460  -87.7008        31
# 1    san patricio      US  28.0170  -97.5169        39
# 2    stephenville      US  32.2207  -98.2023        26
# 3         suances      ES  43.4334   -4.0434        45
# 4     broken hill      AU -31.9500  141.4333        34
# 5   alice springs      AU -23.7000  133.8833        40
# 6         badiyah      OM  22.4500   58.8000        35
# 7          chinde      NP  26.8212   87.7095        37
# 8            tura      IN  25.5198   90.2201        31
# 9          turbat      PK  26.0023   63.0440        26
# 10       calvinia      ZA -31.4707   19.7760        30
# 11           tezu      IN  27.9167   96.1667        49
# 12           atar      MR  20.5169  -13.0499        25
# 13      porbandar      IN  21.6422   69.6093        48

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters radius to search for a hotel+ set empty dictionary
radius = 10000  # (10 kilometers)
params = {
      }

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    

    # Add the current city's latitude and longitude to the params dictionary +API Parameters +API Key
    params["filter"] = f"circle:{row['Lng']},{row['Lat']},{radius}"
    params["bias"] = f"proximity:{row['Lng']},{row['Lat']}"
    params["categories"] = "accommodation.hotel"
    params["api_key"] = geoapify_key

    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make and API request using the params dictionary
    name_address = requests.get(base_url, params=params)

    # Convert the API response to JSON format
    name_address = name_address.json()

    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"

    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# gulf shores - nearest hotel: Beachside Resort
# san patricio - nearest hotel: No hotel found
# stephenville - nearest hotel: The Wyatt
# suances - nearest hotel: Hotel Surfantes
# broken hill - nearest hotel: Ibis Styles
# alice springs - nearest hotel: No hotel found
# badiyah - nearest hotel: Al Areen Hotel Apartments
# chinde - nearest hotel: No hotel found
# tura - nearest hotel: Hotel Polo Orchid
# turbat - nearest hotel: No hotel found
# calvinia - nearest hotel: No hotel found
# tezu - nearest hotel: No hotel found
# atar - nearest hotel: Residence Egueil
# porbandar - nearest hotel: Toran Tourist Bungalow
#              City Country      Lat       Lng  Humidity  \
# 0     gulf shores      US  30.2460  -87.7008        31
# 1    san patricio      US  28.0170  -97.5169        39
# 2    stephenville      US  32.2207  -98.2023        26
# 3         suances      ES  43.4334   -4.0434        45
# 4     broken hill      AU -31.9500  141.4333        34
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot (chat gpt suggestion)
hotel_map_plot = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo=True,
    tiles="OSM",
    frame_width=750,
    frame_height=500,
    size= "Humidity",
    title="Map of Best Weather City Hotels",
    color="Hotel Name",
    legend = "right",
    
)

# Display the map
hotel_map_plot
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (Hotel Name,Humidity)
